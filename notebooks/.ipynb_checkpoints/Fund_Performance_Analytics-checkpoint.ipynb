# %%
import sqlite3
import pandas as pd
import numpy as np

conn = sqlite3.connect('../bluestock_mf.db')

funds = pd.read_sql('SELECT * FROM dim_fund', conn)
nav = pd.read_sql('SELECT * FROM fact_nav', conn)          # nav, daily_return_pct, date, amfi_code
bench = pd.read_sql('SELECT * FROM benchmark_indices', conn)  # index_name, date, close_price
perf = pd.read_sql('SELECT * FROM fact_performance', conn)    # if already partially populated
