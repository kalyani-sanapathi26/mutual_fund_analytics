# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

plt.style.use("seaborn-v0_8")

nav = pd.read_csv("../data/02_nav_history-7.csv")          # amficode, date, nav
fund_master = pd.read_csv("../data/01_fund_master-6.csv")  # amficode, fund_name, category, expense_ratio, etc.
bench = pd.read_csv("../data/10_benchmark_indices-5.csv")  # index_name, date, level/NAV
scheme_perf = pd.read_csv("../data/07_scheme_performance-2.csv")  # if needed for validation
